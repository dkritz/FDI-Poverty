# %%
import pandas as pd
df1 = pd.read_csv("c:/Users/dave/Downloads/FDI_and_Poverty/individual_african_countries.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-989811d41652> in <module>
#       1 import pandas as pd
# ----> 2 df1 = pd.read_csv("c:/Users/dave/Downloads/FDI_and_Poverty/individual_african_countries.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'c:/Users/dave/Downloads/FDI_and_Poverty/individual_african_countries.csv' does not exist: b'c:/Users/dave/Downloads/FDI_and_Poverty/individual_african_countries.csv'

# %%
df1.columns = [c.replace(' ', '_') for c in df1.columns]

df1 = df1.drop("Country_Code", axis=1)
df1 = df1.drop("Series_Code", axis=1)

# %%
africa = df1.melt(id_vars=["Country_Name", "Series_Name"],
        var_name = "Year",
        value_name = "Value")

# %%
africa.dropna(subset=["Value"], axis = 0, inplace = True)

# %%
africa.dtypes
# Out:
# Country_Name    object
# Series_Name     object
# Year            object
# Value           object
# dtype: object

# %%
africa.head()
# Out:
#   Country_Name                                        Series_Name  \
# 0        Benin  Net official development assistance and offici...
# 1        Benin  Foreign direct investment, net inflows (% of GDP)
# 2        Benin         Adjusted net national income (current US$)
# 3        Benin                 Inflation, GDP deflator (annual %)
# 4        Benin  Domestic credit provided by financial sector (...
#
#             Year  Value
# 0  1960_[YR1960]  20000
# 1  1960_[YR1960]     ..
# 2  1960_[YR1960]     ..
# 3  1960_[YR1960]     ..
# 4  1960_[YR1960]     ..

# %%
index = africa.index
columns = africa.columns
values = africa.values

# %%
inflation = africa.loc[africa['Series_Name'] == 'Inflation, GDP deflator (annual %)']
fdi = africa.loc[africa['Series_Name'] == 'Foreign direct investment, net inflows (% of GDP)']
nni = africa.loc[africa['Series_Name'] == 'Adjusted net national income (current US$)']
aid = africa.loc[africa['Series_Name'] == 'Net official development assistance and official aid received (current US$)']
credit = africa.loc[africa['Series_Name'] == 'Domestic credit provided by financial sector (% of GDP)']
poverty_headcount = africa.loc[africa['Series_Name'] == 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)']
primary = africa.loc[africa['Series_Name'] == 'Gross intake ratio in first grade of primary education, total (% of relevant age group)']
poverty_gap = africa.loc[africa['Series_Name'] == 'Poverty gap at $1.90 a day (2011 PPP) (%)']
public = africa.loc[africa['Series_Name'] == 'CPIA public sector management and institutions cluster average (1=low to 6=high)']

# %%
pd.concat([inflation, fdi], axis=1, join='inner')
# Out:
# Empty DataFrame
# Columns: [Country_Name, Series_Name, Year, Value, Country_Name, Series_Name, Year, Value]
# Index: []

# %%
inflation.merge(fdi, left_on=['Country_Name','Year'], right_on=['Country_Name','Year'], how = 'outer')
# Out:
#                   Country_Name                       Series_Name_x  \
# 0                        Benin  Inflation, GDP deflator (annual %)
# 1                       Angola  Inflation, GDP deflator (annual %)
# 2                      Burundi  Inflation, GDP deflator (annual %)
# 3                     Botswana  Inflation, GDP deflator (annual %)
# 4                 Burkina Faso  Inflation, GDP deflator (annual %)
# 5                   Cabo Verde  Inflation, GDP deflator (annual %)
# 10    Foreign direct investment, net inflows (% of GDP)      ..
# 11    Foreign direct investment, net inflows (% of GDP)      ..
# 12    Foreign direct investment, net inflows (% of GDP)      ..
# 13    Foreign direct investment, net inflows (% of GDP)      ..
# 14    Foreign direct investment, net inflows (% of GDP)      ..
# 15    Foreign direct investment, net inflows (% of GDP)      ..
# 16    Foreign direct investment, net inflows (% of GDP)      ..
# 17    Foreign direct investment, net inflows (% of GDP)      ..
# 18    Foreign direct investment, net inflows (% of GDP)      ..
# 19    Foreign direct investment, net inflows (% of GDP)      ..
# 20    Foreign direct investment, net inflows (% of GDP)      ..
# 21    Foreign direct investment, net inflows (% of GDP)      ..
# 22    Foreign direct investment, net inflows (% of GDP)      ..
# 23    Foreign direct investment, net inflows (% of GDP)      ..
# 24    Foreign direct investment, net inflows (% of GDP)      ..
# 25    Foreign direct investment, net inflows (% of GDP)      ..
# 26    Foreign direct investment, net inflows (% of GDP)      ..
# 27    Foreign direct investment, net inflows (% of GDP)      ..
# 28    Foreign direct investment, net inflows (% of GDP)      ..
# 29    Foreign direct investment, net inflows (% of GDP)      ..
# ...                                                 ...     ...
# 3270  Foreign direct investment, net inflows (% of GDP)      ..
# 3271  Foreign direct investment, net inflows (% of GDP)      ..
# 3272  Foreign direct investment, net inflows (% of GDP)      ..
# 3273  Foreign direct investment, net inflows (% of GDP)      ..
# 3274  Foreign direct investment, net inflows (% of GDP)      ..
# 3275  Foreign direct investment, net inflows (% of GDP)      ..
# 3276  Foreign direct investment, net inflows (% of GDP)      ..
# 3277  Foreign direct investment, net inflows (% of GDP)      ..
# 3278  Foreign direct investment, net inflows (% of GDP)      ..
# 3279  Foreign direct investment, net inflows (% of GDP)      ..
# 3280  Foreign direct investment, net inflows (% of GDP)      ..
# 3281  Foreign direct investment, net inflows (% of GDP)      ..
# 3282  Foreign direct investment, net inflows (% of GDP)      ..
# 3283  Foreign direct investment, net inflows (% of GDP)      ..
# 3284  Foreign direct investment, net inflows (% of GDP)      ..
# 3285  Foreign direct investment, net inflows (% of GDP)      ..
# 3286  Foreign direct investment, net inflows (% of GDP)      ..
# 3287  Foreign direct investment, net inflows (% of GDP)      ..
# 3288  Foreign direct investment, net inflows (% of GDP)      ..
# 3289  Foreign direct investment, net inflows (% of GDP)      ..
# 3290  Foreign direct investment, net inflows (% of GDP)      ..
# 3291  Foreign direct investment, net inflows (% of GDP)      ..
# 3292  Foreign direct investment, net inflows (% of GDP)      ..
# 3293  Foreign direct investment, net inflows (% of GDP)      ..
# 3294  Foreign direct investment, net inflows (% of GDP)      ..
# 3295  Foreign direct investment, net inflows (% of GDP)      ..
# 3296  Foreign direct investment, net inflows (% of GDP)      ..
# 3297  Foreign direct investment, net inflows (% of GDP)      ..
# 3298  Foreign direct investment, net inflows (% of GDP)      ..
# 3299  Foreign direct investment, net inflows (% of GDP)      ..
#
# [3300 rows x 6 columns]
