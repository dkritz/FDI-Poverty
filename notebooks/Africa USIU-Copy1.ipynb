# %%
import numpy as np
import pandas as pd
import statsmodels as sm
from linearmodels import PanelOLS
from linearmodels import RandomEffects

# %%
df = pd.read_csv("C:/Users/dave/FDI-Poverty/individual african countries 3Jan20.txt",sep='\t')

# %%
df.describe()
# Out:
#               year       Credit    Education     Inflation  Institutions  \
# count  3245.000000  2441.000000  1586.000000   2590.000000    559.000000
# mean   1989.000000    30.049346    92.729074     30.481127      2.965474
# std      17.032011   111.111967    34.081154    548.468633      0.499505
# min    1960.000000  -114.693670    13.397870    -31.565915      1.400000
# 25%    1974.000000    11.453284    73.082379      2.377842      2.600000
# 50%    1989.000000    20.580087    95.907915      6.697448      3.000000
# 75%    2004.000000    36.611821   108.851045     13.429436      3.300000
# max    2018.000000  4310.716200   267.677610  26765.858000      4.100000
#
#        PovertyGap   PovertyHC        lnFDI        lnGDP        lnODA  \
# count  214.000000  214.000000  2100.000000  1958.000000  3000.000000
# mean    17.293458   41.070093     7.656534     9.549921     7.996078
# std     13.854623   25.143353     1.114116     0.731136     0.856591
# ...

# %%
data = df.set_index(['Ctry','year'])
mod1 = PanelOLS(data.PovertyGap, data[['Credit','Education','Inflation','Institutions','lnFDI','lnGDP']], entity_effects=True, time_effects=True)
res1 = mod1.fit(cov_type='clustered', cluster_entity=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\linearmodels\utility.py:478: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)

# %%
res1
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:             PovertyGap   R-squared:                        0.2422
# Estimator:                   PanelOLS   R-squared (Between):             -88.078
# No. Observations:                  61   R-squared (Within):              -0.2239
# Date:                Mon, Mar 30 2020   R-squared (Overall):             -87.162
# Time:                        08:48:27   Log-likelihood                   -129.06
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.4261
# Entities:                          35   P-value                           0.8427
# Avg Obs:                       1.7429   Distribution:                     F(6,8)
# Min Obs:                       1.0000
# Max Obs:                       4.0000   F-statistic (robust):             0.3861
#                                         P-value                           0.8687
# ...

# %%
data.describe()
# Out:
#             Credit    Education     Inflation  Institutions  PovertyGap  \
# count  2441.000000  1586.000000   2590.000000    559.000000  214.000000
# mean     30.049346    92.729074     30.481127      2.965474   17.293458
# std     111.111967    34.081154    548.468633      0.499505   13.854623
# min    -114.693670    13.397870    -31.565915      1.400000    0.000000
# 25%      11.453284    73.082379      2.377842      2.600000    5.725000
# 50%      20.580087    95.907915      6.697448      3.000000   15.300000
# 75%      36.611821   108.851045     13.429436      3.300000   27.375000
# max    4310.716200   267.677610  26765.858000      4.100000   63.600000
#
#         PovertyHC        lnFDI        lnGDP        lnODA
# count  214.000000  2100.000000  1958.000000  3000.000000
# mean    41.070093     7.656534     9.549921     7.996078
# std     25.143353     1.114116     0.731136     0.856591
# min      0.300000     2.000000     7.430862     4.000000
# ...

# %%
data = df.set_index(['Ctry','year'])
mod2 = PanelOLS(data.PovertyGap, data[['Credit','Education','Inflation','Institutions','lnFDI','lnGDP','lnODA']], entity_effects=True, time_effects=True)
res2 = mod2.fit(cov_type='clustered', cluster_entity=True)

# %%
res2
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:             PovertyGap   R-squared:                        0.2460
# Estimator:                   PanelOLS   R-squared (Between):             -77.908
# No. Observations:                  61   R-squared (Within):              -0.2859
# Date:                Mon, Mar 30 2020   R-squared (Overall):             -77.028
# Time:                        08:50:38   Log-likelihood                   -128.90
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3262
# Entities:                          35   P-value                           0.9187
# Avg Obs:                       1.7429   Distribution:                     F(7,7)
# Min Obs:                       1.0000
# Max Obs:                       4.0000   F-statistic (robust):             0.3223
#                                         P-value                           0.9209
# ...

# %%
data = df.set_index(['Ctry','year'])
mod3 = PanelOLS(data.PovertyHC, data[['Credit','Education','Inflation','Institutions','lnFDI','lnGDP']], entity_effects=True, time_effects=True)
res3 = mod3.fit(cov_type='clustered', cluster_entity=True)

# %%
res3
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              PovertyHC   R-squared:                        0.2594
# Estimator:                   PanelOLS   R-squared (Between):             -2.3534
# No. Observations:                  61   R-squared (Within):              -0.2737
# Date:                Mon, Mar 30 2020   R-squared (Overall):             -2.3269
# Time:                        08:51:39   Log-likelihood                   -141.51
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.4670
# Entities:                          35   P-value                           0.8154
# Avg Obs:                       1.7429   Distribution:                     F(6,8)
# Min Obs:                       1.0000
# Max Obs:                       4.0000   F-statistic (robust):             0.4541
#                                         P-value                           0.8241
# ...

# %%
data = df.set_index(['Ctry','year'])
mod4 = PanelOLS(data.PovertyHC, data[['Credit','Education','Inflation','Institutions','lnFDI','lnGDP','lnODA']], entity_effects=True, time_effects=True)
res4 = mod4.fit(cov_type='clustered', cluster_entity=True)

# %%
res4
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              PovertyHC   R-squared:                        0.2828
# Estimator:                   PanelOLS   R-squared (Between):             -0.3653
# No. Observations:                  61   R-squared (Within):              -0.7260
# Date:                Mon, Mar 30 2020   R-squared (Overall):             -0.3451
# Time:                        08:51:55   Log-likelihood                   -140.53
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.3943
# Entities:                          35   P-value                           0.8787
# Avg Obs:                       1.7429   Distribution:                     F(7,7)
# Min Obs:                       1.0000
# Max Obs:                       4.0000   F-statistic (robust):             0.3408
#                                         P-value                           0.9105
# ...
